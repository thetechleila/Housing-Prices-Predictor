# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, RidgeCV, LassoCV, ElasticNetCV
from sklearn.metrics import mean_squared_error, make_scorer

# %% [markdown]
# ___
# # Ames Housing Dataset: Model **TRAINING**
# ___

# %%
#store houses prices TRAINING data set in variable for readability
train_clean_house = ("/Users/sa14/Desktop/HousePricesKaggle/data/clean_train_data.csv")

#read TRAINING houses prices dataset csv as a dataframe
train_model = pd.read_csv(train_clean_house)

#Set display options to show all columns and rows
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#store houses prices TEST data set in variable for readability
test_clean_house = ("/Users/sa14/Desktop/HousePricesKaggle/data/clean_test_data.csv")

#read TRAINING houses prices dataset csv as a dataframe
test_model = pd.read_csv(test_clean_house)

#Set display options to show all columns and rows
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
test_model.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea LotShape LandContour  \
# 0  1461          20       RH         80.0    11622      Reg         Lvl
# 1  1462          20       RL         81.0    14267      IR1         Lvl
# 2  1463          60       RL         74.0    13830      IR1         Lvl
# 3  1464          60       RL         78.0     9978      IR1         Lvl
# 4  1465         120       RL         43.0     5005      IR1         HLS
#
#   LotConfig Neighborhood Condition1 BldgType HouseStyle  OverallQual  \
# 0    Inside        NAmes      Feedr     1Fam     1Story            5
# 1    Corner        NAmes       Norm     1Fam     1Story            6
# 2    Inside      Gilbert       Norm     1Fam     2Story            5
# 3    Inside      Gilbert       Norm     1Fam     2Story            6
# 4    Inside      StoneBr       Norm   TwnhsE     1Story            8
#
#    OverallCond  YearBuilt  YearRemodAdd Exterior1st Exterior2nd ExterQual  \
# ...

# %%
# Create a list of Features to be stored in "X"

# The Features list will not include "SalePrice" as that will be the target feature
X = train_model.drop(columns=["SalePrice"])  

# Target: "isFraud" column
y = train_model["SalePrice"] 

# train-test-split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.33, 
                                                    random_state=42)

# Set up Scaler then scale existing data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/6k/9kv93tt9525g263ch7552sy80000gn/T/ipykernel_95454/2815585115.py in ?()
#      11                                                     random_state=42)
#      12
#      13 # Set up Scaler then scale existing data
#      14 scaler = StandardScaler()
# ---> 15 X_train = scaler.fit_transform(X_train)
#      16 X_test = scaler.transform(X_test)
#
# /opt/anaconda3/envs/older_python_310/lib/python3.10/site-packages/sklearn/utils/_set_output.py in ?(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#     322             return_tuple = (
#
# ...

# %%
#Get count of rows & columns for X_test and X_train
X_train.shape, X_test.shape
